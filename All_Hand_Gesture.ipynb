# %% [markdown]
# # **Making Dataframe of the matrix of images extracted from the videos.**

# %% [markdown]
# # Import

# %%
import pandas as pd
import cv2
import numpy as np

# %% [markdown]
# # Hand Clapping

# %%
hc = cv2.VideoCapture('handclapping.avi')
hc1 = cv2.VideoCapture('handclapping1.avi')
hc2 = cv2.VideoCapture('handclapping2.avi')
hc3 = cv2.VideoCapture('handclapping3.avi')
hc4 = cv2.VideoCapture('handclapping4.avi')

# %%
##HAND CLAPPING-0
def getFrame(sec):
    hc.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = hc.read()
    if hasFrames:
        cv2.imwrite("imageHc_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

h_c = []
for i in range(1,count):
  a = "imageHc_{}.jpg".format(i)
  h_c.append(a)

resulthc = []
for i in h_c:
  resulthc.append(np.array(cv2.imread(i,0)).flatten())
#resulthc (Remove # to see the result array)

df_hc = pd.DataFrame(resulthc)
df_hc['Action'] = 'Hand Clapping'
#df_hc (Remove # to see the DataFrame)

# %%
##HAND CLAPPING-1
def getFrame(sec):
    hc1.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = hc1.read()
    if hasFrames:
        cv2.imwrite("imageHc1_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

h_c1 = []
for i in range(1,count):
  a = "imageHc1_{}.jpg".format(i)
  h_c1.append(a)

resulthc1 = []
for i in h_c1:
  resulthc1.append(np.array(cv2.imread(i,0)).flatten())
#resulthc (Remove # to see the result array)

df_hc1 = pd.DataFrame(resulthc1)
df_hc1['Action'] = 'Hand Clapping'
#df_hc1 (Remove # to see the DataFrame)

# %%
##HAND CLAPPING-2
def getFrame(sec):
    hc2.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = hc2.read()
    if hasFrames:
        cv2.imwrite("imageHc2_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

h_c2 = []
for i in range(1,count):
  a = "imageHc2_{}.jpg".format(i)
  h_c2.append(a)

resulthc2 = []
for i in h_c2:
  resulthc2.append(np.array(cv2.imread(i,0)).flatten())
#resulthc2 (Remove # to see the result array)

df_hc2 = pd.DataFrame(resulthc2)
df_hc2['Action'] = 'Hand Clapping'
#df_hc2 (Remove # to see the DataFrame)

# %%
##HAND CLAPPING-3
def getFrame(sec):
    hc3.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = hc3.read()
    if hasFrames:
        cv2.imwrite("imageHc3_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

h_c3 = []
for i in range(1,count):
  a = "imageHc3_{}.jpg".format(i)
  h_c3.append(a)

resulthc3 = []
for i in h_c3:
  resulthc3.append(np.array(cv2.imread(i,0)).flatten())
#resulthc3 (Remove # to see the result array)

df_hc3 = pd.DataFrame(resulthc3)
df_hc3['Action'] = 'Hand Clapping'
#df_hc3 (Remove # to see the DataFrame)

# %%
##HAND CLAPPING-4
def getFrame(sec):
    hc4.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = hc4.read()
    if hasFrames:
        cv2.imwrite("imageHc4_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

h_c4 = []
for i in range(1,count):
  a = "imageHc4_{}.jpg".format(i)
  h_c4.append(a)

resulthc4 = []
for i in h_c4:
  resulthc4.append(np.array(cv2.imread(i,0)).flatten())
#resulthc4 (Remove # to see the result array)

df_hc4 = pd.DataFrame(resulthc4)
df_hc4['Action'] = 'Hand Clapping'
#df_hc4 (Remove # to see the DataFrame)

# %% [markdown]
# # Hand Waving

# %%
hw = cv2.VideoCapture('handwaving.avi')
hw1 = cv2.VideoCapture('handwaving1.avi')
hw2 = cv2.VideoCapture('handwaving2.avi')
hw3 = cv2.VideoCapture('handwaving3.avi')
hw4 = cv2.VideoCapture('handwaving4.avi')

# %%
##HAND WAVING-0
def getFrame(sec):
    hw.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = hw.read()
    if hasFrames:
        cv2.imwrite("imageHw_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

h_w = []
for i in range(1,count):
  a = "imageHw_{}.jpg".format(i)
  h_w.append(a)

resulthw = []
for i in h_w:
  resulthw.append(np.array(cv2.imread(i,0)).flatten())
#resulthw (Remove # to see the result array)

df_hw = pd.DataFrame(resulthw)
df_hw['Action'] = 'Hand Waving'
#df_hw (Remove # to see the DataFrame)

# %%
##HAND WAVING-1
def getFrame(sec):
    hw1.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = hw1.read()
    if hasFrames:
        cv2.imwrite("imageHw1_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

h_w1 = []
for i in range(1,count):
  a = "imageHw1_{}.jpg".format(i)
  h_w1.append(a)

resulthw1 = []
for i in h_w1:
  resulthw1.append(np.array(cv2.imread(i,0)).flatten())
#resulthw1 (Remove # to see the result array)

df_hw1 = pd.DataFrame(resulthw1)
df_hw1['Action'] = 'Hand Waving'
#df_hw1 (Remove # to see the DataFrame)

# %%
##HAND WAVING-2
def getFrame(sec):
    hw2.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = hw2.read()
    if hasFrames:
        cv2.imwrite("imageHw2_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

h_w2 = []
for i in range(1,count):
  a = "imageHw2_{}.jpg".format(i)
  h_w2.append(a)

resulthw2 = []
for i in h_w2:
  resulthw2.append(np.array(cv2.imread(i,0)).flatten())
#resulthw2 (Remove # to see the result array)

df_hw2 = pd.DataFrame(resulthw2)
df_hw2['Action'] = 'Hand Waving'
#df_hw2 (Remove # to see the DataFrame)

# %%
##HAND WAVING-3
def getFrame(sec):
    hw3.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = hw3.read()
    if hasFrames:
        cv2.imwrite("imageHw3_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

h_w3 = []
for i in range(1,count):
  a = "imageHw3_{}.jpg".format(i)
  h_w3.append(a)

resulthw3 = []
for i in h_w3:
  resulthw3.append(np.array(cv2.imread(i,0)).flatten())
#resulthw3 (Remove # to see the result array)

df_hw3 = pd.DataFrame(resulthw3)
df_hw3['Action'] = 'Hand Waving'
#df_hw3 (Remove # to see the DataFrame)

# %%
##HAND WAVING-1
def getFrame(sec):
    hw4.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = hw4.read()
    if hasFrames:
        cv2.imwrite("imageHw4_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

h_w4 = []
for i in range(1,count):
  a = "imageHw4_{}.jpg".format(i)
  h_w4.append(a)

resulthw4 = []
for i in h_w4:
  resulthw4.append(np.array(cv2.imread(i,0)).flatten())
#resulthw4 (Remove # to see the result array)

df_hw4 = pd.DataFrame(resulthw4)
df_hw4['Action'] = 'Hand Waving'
#df_hw4 (Remove # to see the DataFrame)

# %% [markdown]
# # Running

# %%
r = cv2.VideoCapture('running.avi')
r1 = cv2.VideoCapture('running1.avi')
r2 = cv2.VideoCapture('running2.avi')
r3 = cv2.VideoCapture('running3.avi')
r4 = cv2.VideoCapture('running4.avi')

# %%
##RUNNING-0
def getFrame(sec):
    r.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = r.read()
    if hasFrames:
        cv2.imwrite("imageR_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

r = []
for i in range(1,count):
  a = "imageR_{}.jpg".format(i)
  r.append(a)

resultr = []
for i in r:
  resultr.append(np.array(cv2.imread(i,0)).flatten())
#resultr (Remove # to see the result array)

df_r = pd.DataFrame(resultr)
df_r['Action'] = 'Running'
#df_r (Remove # to see the DataFrame)

# %%
##RUNNING-1
def getFrame(sec):
    r1.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = r1.read()
    if hasFrames:
        cv2.imwrite("imageR1_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

r1 = []
for i in range(1,count):
  a = "imageR1_{}.jpg".format(i)
  r1.append(a)

resultr1 = []
for i in r1:
  resultr1.append(np.array(cv2.imread(i,0)).flatten())
#resultr1 (Remove # to see the result array)

df_r1 = pd.DataFrame(resultr1)
df_r1['Action'] = 'Running'
#df_r1 (Remove # to see the DataFrame)

# %%
##RUNNING-2
def getFrame(sec):
    r2.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = r2.read()
    if hasFrames:
        cv2.imwrite("imageR2_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

r2 = []
for i in range(1,count):
  a = "imageR2_{}.jpg".format(i)
  r2.append(a)

resultr2 = []
for i in r2:
  resultr2.append(np.array(cv2.imread(i,0)).flatten())
#resultr2 (Remove # to see the result array)

df_r2 = pd.DataFrame(resultr2)
df_r2['Action'] = 'Running'
#df_r2 (Remove # to see the DataFrame)

# %%
##RUNNING-3
def getFrame(sec):
    r3.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = r3.read()
    if hasFrames:
        cv2.imwrite("imageR3_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

r3 = []
for i in range(1,count):
  a = "imageR3_{}.jpg".format(i)
  r3.append(a)

resultr3 = []
for i in r3:
  resultr3.append(np.array(cv2.imread(i,0)).flatten())
#resultr3 (Remove # to see the result array)

df_r3 = pd.DataFrame(resultr3)
df_r3['Action'] = 'Running'
#df_r3 (Remove # to see the DataFrame)

# %%
##RUNNING-4
def getFrame(sec):
    r4.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = r4.read()
    if hasFrames:
        cv2.imwrite("imageR4_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

r4 = []
for i in range(1,count):
  a = "imageR4_{}.jpg".format(i)
  r4.append(a)

resultr4 = []
for i in r4:
  resultr4.append(np.array(cv2.imread(i,0)).flatten())
#resultr4 (Remove # to see the result array)

df_r4 = pd.DataFrame(resultr4)
df_r4['Action'] = 'Running'
#df_r4 (Remove # to see the DataFrame)

# %% [markdown]
# # Walking

# %%
w = cv2.VideoCapture('walking.avi')
w1 = cv2.VideoCapture('walking1.avi')
w2 = cv2.VideoCapture('walking2.avi')
w3 = cv2.VideoCapture('walking3.avi')
w4 = cv2.VideoCapture('walking4.avi')

# %%
##WALKING-0
def getFrame(sec):
    w.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = w.read()
    if hasFrames:
        cv2.imwrite("imageW_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

w = []
for i in range(1,count):
  a = "imageW_{}.jpg".format(i)
  w.append(a)

resultw = []
for i in w:
  resultw.append(np.array(cv2.imread(i,0)).flatten())
#resultw (Remove # to see the result array)

df_w = pd.DataFrame(resultw)
df_w['Action'] = 'Walking'
#df_w (Remove # to see the DataFrame)

# %%
##WALKING-1
def getFrame(sec):
    w1.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = w1.read()
    if hasFrames:
        cv2.imwrite("imageW1_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

w1 = []
for i in range(1,count):
  a = "imageW1_{}.jpg".format(i)
  w1.append(a)

resultw1 = []
for i in w1:
  resultw1.append(np.array(cv2.imread(i,0)).flatten())
#resultrw1 (Remove # to see the result array)

df_w1 = pd.DataFrame(resultw1)
df_w1['Action'] = 'Walking'
#df_w1 (Remove # to see the DataFrame)

# %%
##WALKING-2
def getFrame(sec):
    w2.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = w2.read()
    if hasFrames:
        cv2.imwrite("imageW2_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

w2 = []
for i in range(1,count):
  a = "imageW2_{}.jpg".format(i)
  w2.append(a)

resultw2 = []
for i in w2:
  resultw2.append(np.array(cv2.imread(i,0)).flatten())
#resultrw2 (Remove # to see the result array)

df_w2 = pd.DataFrame(resultw2)
df_w2['Action'] = 'Walking'
#df_w2 (Remove # to see the DataFrame)

# %%
##WALKING-3
def getFrame(sec):
    w3.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = w3.read()
    if hasFrames:
        cv2.imwrite("imageW3_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

w3 = []
for i in range(1,count):
  a = "imageW3_{}.jpg".format(i)
  w3.append(a)

resultw3 = []
for i in w3:
  resultw3.append(np.array(cv2.imread(i,0)).flatten())
#resultrw3 (Remove # to see the result array)

df_w3 = pd.DataFrame(resultw3)
df_w3['Action'] = 'Walking'
#df_w3 (Remove # to see the DataFrame)

# %%
##WALKING-1
def getFrame(sec):
    w4.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = w4.read()
    if hasFrames:
        cv2.imwrite("imageW4_"+str(count)+".jpg", image)     
    return hasFrames
sec = 0
frameRate = 0.05 
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

w4 = []
for i in range(1,count):
  a = "imageW4_{}.jpg".format(i)
  w4.append(a)

resultw4 = []
for i in w4:
  resultw4.append(np.array(cv2.imread(i,0)).flatten())
#resultrw4 (Remove # to see the result array)

df_w4 = pd.DataFrame(resultw4)
df_w4['Action'] = 'Walking'
#df_w4 (Remove # to see the DataFrame)

# %% [markdown]
# # Concatenating All Dataframe

# %%
final_df = pd.concat([df_hc, df_hc1, df_hc2, df_hc3, df_hc4, df_hw, df_hw1, df_hw2, df_hw3, df_hw4, df_r, df_r1, df_r2, df_r3, df_r4, df_w, df_w1, df_w2, df_w3, df_w4], ignore_index=True)
final_df
# Out:
#         0    1    2    3    4  ...  19196  19197  19198  19199         Action
# 0      82   83   88   91   97  ...     62     60     62     57  Hand Clapping
# 1      82   83   88   91   97  ...     62     60     62     57  Hand Clapping
# 2      82   83   88   91   97  ...     62     61     60     57  Hand Clapping
# 3      82   83   88   91   97  ...     62     61     60     57  Hand Clapping
# 4      84   86   90   94   97  ...     62     63     61     59  Hand Clapping
# ...   ...  ...  ...  ...  ...  ...    ...    ...    ...    ...            ...
# 7720  242  240  243  243  247  ...    184    167    170    182        Walking
# 7721  243  241  243  245  247  ...    181    171    178    176        Walking
# 7722  243  241  243  245  247  ...    180    169    176    174        Walking
# 7723  243  241  243  245  247  ...    181    172    177    177        Walking
# 7724  243  244  246  248  249  ...    182    174    173    177        Walking
#
# [7725 rows x 19201 columns]
